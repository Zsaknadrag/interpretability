# %%
path = 'C:\\Users\\Vanda\\Downloads\\avg_lengths.txt'
file = open(path, 'r')
for line in file:
    parts = line.strip().split(' ')
    base = parts[0]
    top = parts[1]
    bot = parts[2]
    diff = float(bot) - float(top)
    if diff >= 1:
        print(base, top, diff)
# Out:
# 1 1.844 1.5559999999999998
# 24 2.156 1.266
# 37 1.778 1.355
# 44 2.467 1.177
# 54 2.244 1.045
# 55 2.311 1.2890000000000001
# 62 2.378 1.2439999999999998
# 64 2.667 1.1110000000000002
# 65 2.867 1.044
# 75 2.178 1.311
# 82 2.378 1.133
# 99 1.889 1.5330000000000001
# 108 2.356 1.3330000000000002
# 117 2.044 1.645
# 122 2.289 1.1109999999999998
# 151 2.178 1.1110000000000002
# 160 2.200 1.3779999999999997
# 177 2.267 1.133
# 180 2.622 1.178
# 192 1.911 1.4449999999999998
# 205 1.778 1.733
# 207 2.244 1.3119999999999998
# 209 2.400 1.044
# 212 1.867 1.666
# 217 2.556 1.4
# 221 2.244 1.2889999999999997
# 222 2.578 1.133
# 224 1.867 2.089
# 226 2.067 1.7109999999999999
# 229 2.333 1.3559999999999999
# 235 2.244 1.1559999999999997
# 239 2.667 1.089
# 246 2.222 1.1560000000000001
# 248 2.200 1.311
# 252 2.244 1.734
# 254 2.000 2.067
# 268 1.778 2.022
# 271 2.111 1.3329999999999997
# 308 2.089 1.355
# 324 2.244 1.6669999999999998
# 326 2.333 1.3559999999999999
# ...
